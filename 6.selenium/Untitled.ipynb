# %%
#step04tourCrawler.py

'''
학습 방법
1. http://tour.interpark.com/ 사이트에서 '파리' 검색해 보기
2. 소스 실행후 분석하기
3. 정규 표현식을 반영해 보기
'''

# pip install BeautifulSoup4
# pip install selenium
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By #https://www.seleniumhq.org/docs/03_webdriver.jsp#locating-ui-elements-webelements

#검색 page가 로딩 되는 시간을 대기하기 위한 모듈
from selenium.webdriver.support.ui import WebDriverWait

# 예외 처리를 위한 모듈
from selenium.webdriver.support import expected_conditions as EC

main_url = "http://tour.interpark.com/"
keyword = "파리"

driver = webdriver.Chrome("C:/driver/chromedriver.exe")
driver.get(main_url)
# time.sleep(3)  # 절대적 : 무조건 정해진 시간(초) 쉬기
driver.implicitly_wait(10) # seconds

# 입력란 찾기 <input id="SearchGNBText" ... >
elem = driver.find_element_by_id("SearchGNBText")
elem.clear()
elem.send_keys(keyword)

# 동작 불가 왜? : 자바스크립트로 구현되어 있기 때문
# elem.submit() 

# 검색 버튼 찾기 <button class="search-btn" ... >
btn_search = driver.find_element_by_css_selector("button.search-btn")
btn_search.click()

'''
1. 검색 후 이동된 화면
2. 검색된 화면 상의 "해외여행" 영역
    - <div class="oTravelBox"></div>
3. div.oTravelBox > ul > li.moreBtnWrap > button
'''
# 검색된 page가 로드되는 시간 대기
# 10 : 초단위
'''
WebDriverWait와 .until 옵션을 통해 우리가 찾고자 하는 HTML 요소를 기다림

By.CLASS_NAME, "oTravelBox"
    - 
    html
        <class_name>
        <.. class="oTravelBox">

'''
try:
    element = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.CLASS_NAME, "oTravelBox"))  #EC:
    )
except Exception as e:
    print("검색 page 로드시 class 속성이 oTravelBox를 얻으려는 중 예외 발생 : ", e)


# "해외여행 더보기" 버튼 클릭
driver.find_element_by_css_selector("div.oTravelBox > ul > li.moreBtnWrap > button").click()

# 페이지가 다 뜨면 진행 할수 있게 묵시적인 설정
# Selenium에서 브라우저 자체가 웹 요소들을 기다리도록 만들어주는 옵션
# 초단위
driver.implicitly_wait(10) # seconds

# 1~2page의 해외여행 정보 스크래핑


for page in range(3, 4):
    try:
        # 자바스크립트 실행
        driver.execute_script("searchModule.SetCategoryList({}, '')".format(page))
        driver.implicitly_wait(5)
        print("{} 페이지로 이동!!!".format(page))

        soup = BeautifulSoup(driver.page_source, "lxml" )

        boxItems = soup.select(".panelZone > .oTravelBox > .boxList > .boxItem")
        
        # print(boxItems)
        for boxItem in boxItems:
            img_src = boxItem.find("img")['src']
            link = boxItem.find("a")['onclick']
            proTitle = boxItem.find("img")['alt']
            proComment = boxItem.find("p", {"class":"proSub"}).text
            # select 는 하나라도 리스트로 리턴
            proPrice = boxItem.select(".proPrice")[0].text
            proPrice = proPrice.replace(" ", "")
            proPrice = proPrice.replace("\n", "")
            tag_period = boxItem.select(".proInfo")[0]
            tag_period.find('span').replace_with('')  # <span> 태그 없애기
            proPeriod = tag_period.text
            proJumsu = boxItem.select(".proInfo")[2].text

            print("썸네일=", img_src)
            print("링크=", link)
            print("상품명=", proTitle)
            print("코멘트=", proComment)
            print("가격=", proPrice)
            print("여행기간=", proPeriod)
            print("평점=", proJumsu)
            print("=" * 100)
    except Exception as e:
        print("페이지 파싱 에러", e)
    finally:
        time.sleep(5)
        driver.close()
# Out:
# 3 페이지로 이동!!!
# 썸네일= http://tourimage.interpark.com/product/tour/00161/D30/280/D3010432_1_610.JPG
# 링크= searchModule.OnClickDetail('http://tour.interpark.com/goods/detail/?BaseGoodsCd=D3010432','http://cc.toast.com/cc?a=kw8LaYJ2TBEepMn&m=0&sid=y5vqp3wb33rplu4ocnzzxvqw&pgid=56321b8bcd47b64650c6d5f47afd4fd1&query=%ED%8C%8C%EB%A6%AC&platform=tour:nx:pc&adid=&sub_service=tourR&u=http%3a%2f%2fmtour.interpark.com%2ftour%2fGoods.aspx%3fbaseGoodsCD%3dD3010432&area=main&c=TourGoods:RDD3010432&q=%ed%8c%8c%eb%a6%ac')
# 상품명= L.o.v.e. I.n 부산출발 파리♥ 자유허니문 6일
# 코멘트= 부산출발/자유허니문
# 가격= 2,200,000원~
# 여행기간= 여행 기간 : 4박6일
# 평점= 평점 0
# ====================================================================================================
# 썸네일= http://tourimage.interpark.com/product/tour/00161/D30/280/D3010480_1_267.JPG
# 링크= searchModule.OnClickDetail('http://tour.interpark.com/goods/detail/?BaseGoodsCd=D3010480','http://cc.toast.com/cc?a=kw8LaYJ2TBEepMn&m=0&sid=y5vqp3wb33rplu4ocnzzxvqw&pgid=56321b8bcd47b64650c6d5f47afd4fd1&query=%ED%8C%8C%EB%A6%AC&platform=tour:nx:pc&adid=&sub_service=tourR&u=http%3a%2f%2fmtour.interpark.com%2ftour%2fGoods.aspx%3fbaseGoodsCD%3dD3010480&area=main&c=TourGoods:RDD3010480&q=%ed%8c%8c%eb%a6%ac')
# 상품명= [유럽 허니문] 럭셔리 파리 & 프라하 7일
# 코멘트= 낭만과 로맨틱의 대명사인 파리와 중세시대의 모습이 간직된 프라하
# 가격= 2,650,000원~
# 여행기간= 여행 기간 : 4박7일
# 평점= 평점 0
# ====================================================================================================
# 썸네일= http://tourimage.interpark.com/product/tour/00161/B30/280/B3010968_9_770.jpg
# 링크= searchModule.OnClickDetail('http://tour.interpark.com/goods/detail/?BaseGoodsCd=B3010968','http://cc.toast.com/cc?a=kw8LaYJ2TBEepMn&m=0&sid=y5vqp3wb33rplu4ocnzzxvqw&pgid=56321b8bcd47b64650c6d5f47afd4fd1&query=%ED%8C%8C%EB%A6%AC&platform=tour:nx:pc&adid=&sub_service=tourR&u=http%3a%2f%2fmtour.interpark.com%2ftour%2fGoods.aspx%3fbaseGoodsCD%3dB3010968&area=main&c=TourGoods:RBB3010968&q=%ed%8c%8c%eb%a6%ac')
# 상품명= [직항특가] 파리 자유여행 6일
# 코멘트= 직항으로 떠나는 낭만의 도시
# 가격= 1,456,000원~
# 여행기간= 여행 기간 : 4박6일
# 평점= 평점 9.1
# ====================================================================================================
# 썸네일= http://tourimage.interpark.com/product/tour/00161/B30/280/B3010980_4_810.jpg
# 링크= searchModule.OnClickDetail('http://tour.interpark.com/goods/detail/?BaseGoodsCd=B3010980','http://cc.toast.com/cc?a=kw8LaYJ2TBEepMn&m=0&sid=y5vqp3wb33rplu4ocnzzxvqw&pgid=56321b8bcd47b64650c6d5f47afd4fd1&query=%ED%8C%8C%EB%A6%AC&platform=tour:nx:pc&adid=&sub_service=tourR&u=http%3a%2f%2fmtour.interpark.com%2ftour%2fGoods.aspx%3fbaseGoodsCD%3dB3010980&area=main&c=TourGoods:RBB3010980&q=%ed%8c%8c%eb%a6%ac')
# 상품명= 니스 / 파리 7일
# 코멘트= 파리PLUS
# 가격= 1,750,000원~
# 여행기간= 여행 기간 : 5박7일
# 평점= 평점 0
# ====================================================================================================
# 썸네일= http://tourimage.interpark.com/product/tour/00161/B30/280/B3011250_8_180.jpg
# 링크= searchModule.OnClickDetail('http://tour.interpark.com/goods/detail/?BaseGoodsCd=B3011250','http://cc.toast.com/cc?a=kw8LaYJ2TBEepMn&m=0&sid=y5vqp3wb33rplu4ocnzzxvqw&pgid=56321b8bcd47b64650c6d5f47afd4fd1&query=%ED%8C%8C%EB%A6%AC&platform=tour:nx:pc&adid=&sub_service=tourR&u=http%3a%2f%2fmtour.interpark.com%2ftour%2fGoods.aspx%3fbaseGoodsCD%3dB3011250&area=main&c=TourGoods:RBB3011250&q=%ed%8c%8c%eb%a6%ac')
# 상품명= 파리/스위스/로마 9일
# 코멘트= [대한항공직항]
# 가격= 2,412,400원~
# 여행기간= 여행 기간 : 7박9일
# 평점= 평점 0
# ====================================================================================================
# 썸네일= http://tourimage.interpark.com/product/tour/00161/A30/280/A3015059_1_700.jpg
# 링크= searchModule.OnClickDetail('http://tour.interpark.com/goods/detail/?BaseGoodsCd=A3015059','http://cc.toast.com/cc?a=kw8LaYJ2TBEepMn&m=0&sid=y5vqp3wb33rplu4ocnzzxvqw&pgid=56321b8bcd47b64650c6d5f47afd4fd1&query=%ED%8C%8C%EB%A6%AC&platform=tour:nx:pc&adid=&sub_service=tourR&u=http%3a%2f%2fmtour.interpark.com%2ftour%2fGoods.aspx%3fbaseGoodsCD%3dA3015059&area=main&c=TourGoods:RAA3015059&q=%ed%8c%8c%eb%a6%ac')
# 상품명= [온라인박람회][파리야경/곤돌라포함]★서유럽3국8일_리기/루체른
# 코멘트= [NO환율차액분]서유럽최대판매/인기상품
# 가격= 1,550,000원~
# 여행기간= 여행 기간 : 5박8일
# 평점= 평점 0
# ====================================================================================================
# 썸네일= http://tourimage.interpark.com/product/tour/00161/B30/280/B3010098_12_030.jpg
# 링크= searchModule.OnClickDetail('http://tour.interpark.com/goods/detail/?BaseGoodsCd=B3010098','http://cc.toast.com/cc?a=kw8LaYJ2TBEepMn&m=0&sid=y5vqp3wb33rplu4ocnzzxvqw&pgid=56321b8bcd47b64650c6d5f47afd4fd1&query=%ED%8C%8C%EB%A6%AC&platform=tour:nx:pc&adid=&sub_service=tourR&u=http%3a%2f%2fmtour.interpark.com%2ftour%2fGoods.aspx%3fbaseGoodsCD%3dB3010098&area=main&c=TourGoods:RBB3010098&q=%ed%8c%8c%eb%a6%ac')
# 상품명= [온라인박람회]프라하/파리 자유여행 7일
# 코멘트= 사랑스러운 나의 도시
# 가격= 1,500,000원~
# 여행기간= 여행 기간 : 5박7일
# 평점= 평점 9.2
# ====================================================================================================
# 썸네일= http://tourimage.interpark.com/product/tour/00161/D30/280/D3010394_46_170.JPG
# 링크= searchModule.OnClickDetail('http://tour.interpark.com/goods/detail/?BaseGoodsCd=D3010394','http://cc.toast.com/cc?a=kw8LaYJ2TBEepMn&m=0&sid=y5vqp3wb33rplu4ocnzzxvqw&pgid=56321b8bcd47b64650c6d5f47afd4fd1&query=%ED%8C%8C%EB%A6%AC&platform=tour:nx:pc&adid=&sub_service=tourR&u=http%3a%2f%2fmtour.interpark.com%2ftour%2fGoods.aspx%3fbaseGoodsCD%3dD3010394&area=main&c=TourGoods:RDD3010394&q=%ed%8c%8c%eb%a6%ac')
# 상품명= L.o.v.e. I.n 스위스♥파리 자유허니문 7일
# 코멘트= 알프스에서 파리 까지~!
# 가격= 2,585,100원~
# 여행기간= 여행 기간 : 4박7일
# 평점= 평점 0
# ====================================================================================================
# 썸네일= http://tourimage.interpark.com/product/tour/00161/D30/280/D3010397_1_837.jpg
# 링크= searchModule.OnClickDetail('http://tour.interpark.com/goods/detail/?BaseGoodsCd=D3010397','http://cc.toast.com/cc?a=kw8LaYJ2TBEepMn&m=0&sid=y5vqp3wb33rplu4ocnzzxvqw&pgid=56321b8bcd47b64650c6d5f47afd4fd1&query=%ED%8C%8C%EB%A6%AC&platform=tour:nx:pc&adid=&sub_service=tourR&u=http%3a%2f%2fmtour.interpark.com%2ftour%2fGoods.aspx%3fbaseGoodsCD%3dD3010397&area=main&c=TourGoods:RDD3010397&q=%ed%8c%8c%eb%a6%ac')
# 상품명= L.o.v.e. I.n 파리♥이탈리아 자유허니문 8일
# 코멘트= 클래식 유럽허니문~!
# 가격= 2,540,000원~
# 여행기간= 여행 기간 : 6박8일
# 평점= 평점 10
# ====================================================================================================
# 썸네일= http://tourimage.interpark.com/product/tour/00161/B30/280/B3010748_7_353.jpg
# 링크= searchModule.OnClickDetail('http://tour.interpark.com/goods/detail/?BaseGoodsCd=B3010748','http://cc.toast.com/cc?a=kw8LaYJ2TBEepMn&m=0&sid=y5vqp3wb33rplu4ocnzzxvqw&pgid=56321b8bcd47b64650c6d5f47afd4fd1&query=%ED%8C%8C%EB%A6%AC&platform=tour:nx:pc&adid=&sub_service=tourR&u=http%3a%2f%2fmtour.interpark.com%2ftour%2fGoods.aspx%3fbaseGoodsCD%3dB3010748&area=main&c=TourGoods:RBB3010748&q=%ed%8c%8c%eb%a6%ac')
# 상품명= [온라인박람회] 베를린 / 파리 7일
# 코멘트= 핫피플의  성지~!
# 가격= 1,650,000원~
# 여행기간= 여행 기간 : 5박7일
# 평점= 평점 10
# ====================================================================================================
